# %% [markdown]
# # Environment Setup

# %%
#!pip install gym gym-retro, opencv-python

# %%
# PPO algorythm
from stable_baselines3 import PPO
# Monitor for logging 
from stable_baselines3.common.monitor import Monitor
# Vec wrappers to vectorize and frame stack
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
# To deal with filepaths
import os

# %%
# Running Environment_Setup.ipynb to download ROM and setup custom Sonic environment.
# %run Environment_Setup.ipynb
# Out:
# Importing SonicTheHedgehog2-Genesis
# Imported 1 games

# %%
LOG_DIR = './logs/'

# %%
# Create environment 
env = Sonic()
env.level(1)
env = ActionDiscretizer(env)
env = Monitor(env, LOG_DIR)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')

# %% [markdown]
# # Setup Callback To Monitor Training Process

# %%
#!pip install stable-baselines3[extra]

# %%
# Import base callback 
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'

# %%
callback = TrainAndLoggingCallback(check_freq=100_000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # Continuing Training Best Model

# %%
# Best model
model = PPO.load("train/old_gen/PPO_Sonic_lvl1", env, verbose=1, tensorboard_log=LOG_DIR)

# Displaying current learning rate 
print(model.learning_rate)
print(model.n_steps)
# Out:
# Wrapping the env in a VecTransposeImage.
# 1.4336960770105995e-06
# 8192

# %%
# Lowering learning rate if needed
model.learning_rate /= 1.2
print(model.learning_rate)
# Out:
# 4.580372217810106e-05

# %%
# Training
model.learn(total_timesteps=4_000_000, callback=callback)
# Out:
# Logging to ./logs/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 236  |
# |    iterations      | 1    |
# |    time_elapsed    | 34   |
# |    total_timesteps | 8192 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 2           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003872884 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 12.6        |
# |    n_updates            | 17330       |
# |    policy_gradient_loss | -0.000556   |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 180          |
# |    iterations           | 3            |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0051304884 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.417       |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 12.3         |
# |    n_updates            | 17340        |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 132          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 4            |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0026324722 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.389       |
# |    explained_variance   | -0.343       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.427        |
# |    n_updates            | 17350        |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 2.73         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.07e+04   |
# |    ep_rew_mean          | 715        |
# | time/                   |            |
# |    fps                  | 162        |
# |    iterations           | 5          |
# |    time_elapsed         | 252        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00316177 |
# |    clip_fraction        | 0.0286     |
# |    clip_range           | 0.236      |
# |    entropy_loss         | -0.328     |
# |    explained_variance   | -0.96      |
# |    learning_rate        | 1.43e-06   |
# |    loss                 | 0.115      |
# |    n_updates            | 17360      |
# |    policy_gradient_loss | -0.00221   |
# |    value_loss           | 0.508      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.07e+04     |
# |    ep_rew_mean          | 715          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 6            |
# |    time_elapsed         | 307          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0026369388 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.282       |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.254        |
# |    n_updates            | 17370        |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 9.68         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.07e+04    |
# |    ep_rew_mean          | 715         |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 7           |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.002422069 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 2.23        |
# |    n_updates            | 17380       |
# |    policy_gradient_loss | -0.000608   |
# |    value_loss           | 65.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.07e+04     |
# |    ep_rew_mean          | 715          |
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 8            |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0015619074 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -4.99        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0507       |
# |    n_updates            | 17390        |
# |    policy_gradient_loss | -0.000366    |
# |    value_loss           | 0.0978       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.07e+04     |
# |    ep_rew_mean          | 715          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 9            |
# |    time_elapsed         | 474          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0040429737 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.719       |
# |    explained_variance   | -5.86        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0222       |
# |    n_updates            | 17400        |
# |    policy_gradient_loss | -0.000677    |
# |    value_loss           | 0.0558       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.07e+04    |
# |    ep_rew_mean          | 715         |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 10          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007413907 |
# |    clip_fraction        | 0.0384      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | -10.6       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.00867     |
# |    n_updates            | 17410       |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 0.0471      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.22e+04     |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 11           |
# |    time_elapsed         | 573          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0070188744 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.665        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0148       |
# |    n_updates            | 17420        |
# |    policy_gradient_loss | -0.000773    |
# |    value_loss           | 0.458        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.22e+04    |
# |    ep_rew_mean          | 491         |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 12          |
# |    time_elapsed         | 626         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004080835 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 5           |
# |    n_updates            | 17430       |
# |    policy_gradient_loss | -7.15e-05   |
# |    value_loss           | 94.4        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4.22e+04      |
# |    ep_rew_mean          | 491           |
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 13            |
# |    time_elapsed         | 683           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00073679106 |
# |    clip_fraction        | 0.0117        |
# |    clip_range           | 0.236         |
# |    entropy_loss         | -0.218        |
# |    explained_variance   | 0.379         |
# |    learning_rate        | 1.43e-06      |
# |    loss                 | 49.5          |
# |    n_updates            | 17440         |
# |    policy_gradient_loss | -0.000817     |
# |    value_loss           | 84.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.22e+04     |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 14           |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0010207072 |
# |    clip_fraction        | 0.0079       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.287       |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 94.5         |
# |    n_updates            | 17450        |
# |    policy_gradient_loss | -0.000588    |
# |    value_loss           | 24.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.22e+04     |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 15           |
# |    time_elapsed         | 792          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0005867459 |
# |    clip_fraction        | 0.00603      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.174       |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 2.69         |
# |    n_updates            | 17460        |
# |    policy_gradient_loss | -0.000395    |
# |    value_loss           | 2.16         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.22e+04     |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 16           |
# |    time_elapsed         | 849          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0028201821 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 91.7         |
# |    n_updates            | 17470        |
# |    policy_gradient_loss | -0.000428    |
# |    value_loss           | 20.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.22e+04     |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 17           |
# |    time_elapsed         | 896          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0018217674 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.407        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 2.66         |
# |    n_updates            | 17480        |
# |    policy_gradient_loss | -0.000575    |
# |    value_loss           | 51.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.22e+04     |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 155          |
# |    iterations           | 18           |
# |    time_elapsed         | 947          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0101606455 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | -1.88        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0778       |
# |    n_updates            | 17490        |
# |    policy_gradient_loss | 8.16e-05     |
# |    value_loss           | 0.288        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.22e+04    |
# |    ep_rew_mean          | 491         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 19          |
# |    time_elapsed         | 998         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.008263661 |
# |    clip_fraction        | 0.0247      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.795      |
# |    explained_variance   | -1.84       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.0775      |
# |    n_updates            | 17500       |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+04    |
# |    ep_rew_mean          | 620         |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 20          |
# |    time_elapsed         | 1049        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.004706449 |
# |    clip_fraction        | 0.0162      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.785      |
# |    explained_variance   | -4.82       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.00684     |
# |    n_updates            | 17510       |
# |    policy_gradient_loss | -0.000696   |
# |    value_loss           | 0.0571      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+04    |
# |    ep_rew_mean          | 620         |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 21          |
# |    time_elapsed         | 1100        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.002578272 |
# |    clip_fraction        | 0.00748     |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 13.4        |
# |    n_updates            | 17520       |
# |    policy_gradient_loss | -0.000619   |
# |    value_loss           | 71.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 22           |
# |    time_elapsed         | 1150         |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0035401788 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.344       |
# |    explained_variance   | 0.506        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 66.9         |
# |    n_updates            | 17530        |
# |    policy_gradient_loss | -0.000361    |
# |    value_loss           | 151          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 23           |
# |    time_elapsed         | 1198         |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0009407727 |
# |    clip_fraction        | 0.00878      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.195       |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.948        |
# |    n_updates            | 17540        |
# |    policy_gradient_loss | -0.000113    |
# |    value_loss           | 1.89         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 24           |
# |    time_elapsed         | 1248         |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0038226808 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.384       |
# |    explained_variance   | -0.311       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.201        |
# |    n_updates            | 17550        |
# |    policy_gradient_loss | -0.000627    |
# |    value_loss           | 0.69         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 25           |
# |    time_elapsed         | 1297         |
# |    total_timesteps      | 204800       |
# | train/                  |              |
# |    approx_kl            | 0.0017366369 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 59.7         |
# |    n_updates            | 17560        |
# |    policy_gradient_loss | -0.000455    |
# |    value_loss           | 65.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 26           |
# |    time_elapsed         | 1347         |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0030350888 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | -3.88        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.211        |
# |    n_updates            | 17570        |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 0.539        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 27           |
# |    time_elapsed         | 1396         |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0020945366 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.081        |
# |    n_updates            | 17580        |
# |    policy_gradient_loss | -0.000561    |
# |    value_loss           | 1.24         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 28           |
# |    time_elapsed         | 1449         |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0069676694 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.753       |
# |    explained_variance   | -2.7         |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0738       |
# |    n_updates            | 17590        |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 0.236        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+04    |
# |    ep_rew_mean          | 620         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 29          |
# |    time_elapsed         | 1499        |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.008547537 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.738      |
# |    explained_variance   | -4.11       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.0486      |
# |    n_updates            | 17600       |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 0.13        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 30           |
# |    time_elapsed         | 1548         |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0076540057 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.707       |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 2.86         |
# |    n_updates            | 17610        |
# |    policy_gradient_loss | 0.0011       |
# |    value_loss           | 24.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 31           |
# |    time_elapsed         | 1600         |
# |    total_timesteps      | 253952       |
# | train/                  |              |
# |    approx_kl            | 0.0039188936 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.681       |
# |    explained_variance   | -2.04        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.137        |
# |    n_updates            | 17620        |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 0.537        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+04     |
# |    ep_rew_mean          | 620          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 32           |
# |    time_elapsed         | 1653         |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0029098936 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | -6.83        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0125       |
# |    n_updates            | 17630        |
# |    policy_gradient_loss | -0.000723    |
# |    value_loss           | 0.109        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.66e+04    |
# |    ep_rew_mean          | 590         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 33          |
# |    time_elapsed         | 1705        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.002178057 |
# |    clip_fraction        | 0.01        |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -8.65       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.0337      |
# |    n_updates            | 17640       |
# |    policy_gradient_loss | -0.000416   |
# |    value_loss           | 0.0786      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.66e+04     |
# |    ep_rew_mean          | 590          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 34           |
# |    time_elapsed         | 1756         |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0011338831 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 1.52         |
# |    n_updates            | 17650        |
# |    policy_gradient_loss | -0.000347    |
# |    value_loss           | 72.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.66e+04    |
# |    ep_rew_mean          | 590         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 35          |
# |    time_elapsed         | 1808        |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.007077744 |
# |    clip_fraction        | 0.0139      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | -3.28       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.0361      |
# |    n_updates            | 17660       |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 0.0768      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.66e+04    |
# |    ep_rew_mean          | 590         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 36          |
# |    time_elapsed         | 1859        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005455155 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | -5.28       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.00541     |
# |    n_updates            | 17670       |
# |    policy_gradient_loss | -4.21e-05   |
# |    value_loss           | 0.0486      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.66e+04     |
# |    ep_rew_mean          | 590          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 37           |
# |    time_elapsed         | 1909         |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.0015435521 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | -7.14        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0164       |
# |    n_updates            | 17680        |
# |    policy_gradient_loss | 0.000268     |
# |    value_loss           | 0.0501       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.66e+04     |
# |    ep_rew_mean          | 590          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 38           |
# |    time_elapsed         | 1960         |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0034280038 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.651       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 1.02         |
# |    n_updates            | 17690        |
# |    policy_gradient_loss | -0.000423    |
# |    value_loss           | 0.725        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.66e+04    |
# |    ep_rew_mean          | 590         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 39          |
# |    time_elapsed         | 2011        |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.009924082 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 42.1        |
# |    n_updates            | 17700       |
# |    policy_gradient_loss | -0.000606   |
# |    value_loss           | 166         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.66e+04     |
# |    ep_rew_mean          | 590          |
# | time/                   |              |
# |    fps                  | 158          |
# |    iterations           | 40           |
# |    time_elapsed         | 2061         |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0016792566 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.121       |
# |    explained_variance   | -0.123       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 64.5         |
# |    n_updates            | 17710        |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 80.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 41           |
# |    time_elapsed         | 2111         |
# |    total_timesteps      | 335872       |
# | train/                  |              |
# |    approx_kl            | 0.0025050915 |
# |    clip_fraction        | 0.00551      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | 0.369        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 1.47         |
# |    n_updates            | 17720        |
# |    policy_gradient_loss | 3.28e-05     |
# |    value_loss           | 6.47         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 42           |
# |    time_elapsed         | 2163         |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0022859408 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.297       |
# |    explained_variance   | 0.0914       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 15.1         |
# |    n_updates            | 17730        |
# |    policy_gradient_loss | -0.000534    |
# |    value_loss           | 68.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.58e+04    |
# |    ep_rew_mean          | 662         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 43          |
# |    time_elapsed         | 2213        |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.006287414 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.337      |
# |    explained_variance   | 0.0554      |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 5.31        |
# |    n_updates            | 17740       |
# |    policy_gradient_loss | 0.000486    |
# |    value_loss           | 255         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.58e+04    |
# |    ep_rew_mean          | 662         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 44          |
# |    time_elapsed         | 2264        |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.004162453 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.396      |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 3.62        |
# |    n_updates            | 17750       |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 46          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 45           |
# |    time_elapsed         | 2316         |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0046005356 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | -4.17        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0367       |
# |    n_updates            | 17760        |
# |    policy_gradient_loss | 0.000266     |
# |    value_loss           | 0.0896       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.58e+04    |
# |    ep_rew_mean          | 662         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 46          |
# |    time_elapsed         | 2367        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.003942183 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.532      |
# |    explained_variance   | -7.25       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.0325      |
# |    n_updates            | 17770       |
# |    policy_gradient_loss | -0.000117   |
# |    value_loss           | 0.0446      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 47           |
# |    time_elapsed         | 2417         |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 0.0024131592 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | -6.23        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0178       |
# |    n_updates            | 17780        |
# |    policy_gradient_loss | -3.89e-05    |
# |    value_loss           | 0.0348       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 48           |
# |    time_elapsed         | 2469         |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0010918437 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.387        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.988        |
# |    n_updates            | 17790        |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 19.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 49           |
# |    time_elapsed         | 2519         |
# |    total_timesteps      | 401408       |
# | train/                  |              |
# |    approx_kl            | 0.0019267013 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.318       |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 6.64         |
# |    n_updates            | 17800        |
# |    policy_gradient_loss | -0.000931    |
# |    value_loss           | 36.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 50           |
# |    time_elapsed         | 2566         |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0011564975 |
# |    clip_fraction        | 0.00905      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.886        |
# |    n_updates            | 17810        |
# |    policy_gradient_loss | -0.000538    |
# |    value_loss           | 18.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.58e+04     |
# |    ep_rew_mean          | 662          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 51           |
# |    time_elapsed         | 2612         |
# |    total_timesteps      | 417792       |
# | train/                  |              |
# |    approx_kl            | 0.0052554114 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | -0.44        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.492        |
# |    n_updates            | 17820        |
# |    policy_gradient_loss | -0.000841    |
# |    value_loss           | 1.53         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7e+04        |
# |    ep_rew_mean          | 721          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 52           |
# |    time_elapsed         | 2666         |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0023784314 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.415       |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 15.6         |
# |    n_updates            | 17830        |
# |    policy_gradient_loss | -0.000273    |
# |    value_loss           | 121          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7e+04        |
# |    ep_rew_mean          | 721          |
# | time/                   |              |
# |    fps                  | 159          |
# |    iterations           | 53           |
# |    time_elapsed         | 2717         |
# |    total_timesteps      | 434176       |
# | train/                  |              |
# |    approx_kl            | 0.0008129274 |
# |    clip_fraction        | 0.00266      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.198       |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 1.62         |
# |    n_updates            | 17840        |
# |    policy_gradient_loss | -0.000613    |
# |    value_loss           | 8.49         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7e+04         |
# |    ep_rew_mean          | 721           |
# | time/                   |               |
# |    fps                  | 159           |
# |    iterations           | 54            |
# |    time_elapsed         | 2769          |
# |    total_timesteps      | 442368        |
# | train/                  |               |
# |    approx_kl            | 0.00018307901 |
# |    clip_fraction        | 0.00145       |
# |    clip_range           | 0.236         |
# |    entropy_loss         | -0.0853       |
# |    explained_variance   | 0.249         |
# |    learning_rate        | 1.43e-06      |
# |    loss                 | 1.34          |
# |    n_updates            | 17850         |
# |    policy_gradient_loss | -3.05e-05     |
# |    value_loss           | 37.2          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 7e+04         |
# |    ep_rew_mean          | 721           |
# | time/                   |               |
# |    fps                  | 159           |
# |    iterations           | 55            |
# |    time_elapsed         | 2820          |
# |    total_timesteps      | 450560        |
# | train/                  |               |
# |    approx_kl            | 0.00079693017 |
# |    clip_fraction        | 0.00557       |
# |    clip_range           | 0.236         |
# ...
# |    iterations           | 377          |
# |    time_elapsed         | 22689        |
# |    total_timesteps      | 3088384      |
# | train/                  |              |
# |    approx_kl            | 0.0015064304 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -0.344       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.143        |
# |    n_updates            | 21080        |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 0.417        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.08e+04     |
# |    ep_rew_mean          | -48          |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 378          |
# |    time_elapsed         | 22746        |
# |    total_timesteps      | 3096576      |
# | train/                  |              |
# |    approx_kl            | 0.0001668708 |
# |    clip_fraction        | 0.00245      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | -1.35        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0103       |
# |    n_updates            | 21090        |
# |    policy_gradient_loss | -0.000292    |
# |    value_loss           | 0.211        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.08e+04    |
# |    ep_rew_mean          | -48         |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 379         |
# |    time_elapsed         | 22805       |
# |    total_timesteps      | 3104768     |
# | train/                  |             |
# |    approx_kl            | 0.004062575 |
# |    clip_fraction        | 0.0152      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | -0.513      |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 0.535       |
# |    n_updates            | 21100       |
# |    policy_gradient_loss | -0.000202   |
# |    value_loss           | 6.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 380          |
# |    time_elapsed         | 22867        |
# |    total_timesteps      | 3112960      |
# | train/                  |              |
# |    approx_kl            | 0.0024085795 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.363       |
# |    explained_variance   | -0.937       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.26         |
# |    n_updates            | 21110        |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.562        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.13e+04    |
# |    ep_rew_mean          | -51.4       |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 381         |
# |    time_elapsed         | 22933       |
# |    total_timesteps      | 3121152     |
# | train/                  |             |
# |    approx_kl            | 0.001170987 |
# |    clip_fraction        | 0.0069      |
# |    clip_range           | 0.236       |
# |    entropy_loss         | -0.201      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 1.43e-06    |
# |    loss                 | 46.8        |
# |    n_updates            | 21120       |
# |    policy_gradient_loss | 0.000307    |
# |    value_loss           | 149         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 382          |
# |    time_elapsed         | 22993        |
# |    total_timesteps      | 3129344      |
# | train/                  |              |
# |    approx_kl            | 0.0012552413 |
# |    clip_fraction        | 0.00618      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.0196      |
# |    explained_variance   | -0.692       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0217       |
# |    n_updates            | 21130        |
# |    policy_gradient_loss | 0.00118      |
# |    value_loss           | 0.0758       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 383          |
# |    time_elapsed         | 23055        |
# |    total_timesteps      | 3137536      |
# | train/                  |              |
# |    approx_kl            | 0.0005829991 |
# |    clip_fraction        | 0.00558      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.0976      |
# |    explained_variance   | 0.0825       |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.079        |
# |    n_updates            | 21140        |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 0.336        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 384          |
# |    time_elapsed         | 23116        |
# |    total_timesteps      | 3145728      |
# | train/                  |              |
# |    approx_kl            | 0.0004639384 |
# |    clip_fraction        | 0.00284      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.0668      |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0325       |
# |    n_updates            | 21150        |
# |    policy_gradient_loss | 0.000105     |
# |    value_loss           | 0.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 385          |
# |    time_elapsed         | 23177        |
# |    total_timesteps      | 3153920      |
# | train/                  |              |
# |    approx_kl            | 0.0009231586 |
# |    clip_fraction        | 0.00503      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.141       |
# |    explained_variance   | 0.337        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 8.94         |
# |    n_updates            | 21160        |
# |    policy_gradient_loss | -0.000786    |
# |    value_loss           | 44.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 386          |
# |    time_elapsed         | 23238        |
# |    total_timesteps      | 3162112      |
# | train/                  |              |
# |    approx_kl            | 0.0009297672 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | -2.77        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.00717      |
# |    n_updates            | 21170        |
# |    policy_gradient_loss | -0.000661    |
# |    value_loss           | 0.117        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 387          |
# |    time_elapsed         | 23298        |
# |    total_timesteps      | 3170304      |
# | train/                  |              |
# |    approx_kl            | 0.0010752697 |
# |    clip_fraction        | 0.00574      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | -0.0696      |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.861        |
# |    n_updates            | 21180        |
# |    policy_gradient_loss | -0.00022     |
# |    value_loss           | 0.674        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 388          |
# |    time_elapsed         | 23359        |
# |    total_timesteps      | 3178496      |
# | train/                  |              |
# |    approx_kl            | 0.0005039817 |
# |    clip_fraction        | 0.00648      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.204       |
# |    explained_variance   | -2.56        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0158       |
# |    n_updates            | 21190        |
# |    policy_gradient_loss | 3.62e-06     |
# |    value_loss           | 0.0607       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 389          |
# |    time_elapsed         | 23421        |
# |    total_timesteps      | 3186688      |
# | train/                  |              |
# |    approx_kl            | 0.0015883216 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | 0.29         |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.142        |
# |    n_updates            | 21200        |
# |    policy_gradient_loss | 0.000232     |
# |    value_loss           | 0.935        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.13e+04      |
# |    ep_rew_mean          | -51.4         |
# | time/                   |               |
# |    fps                  | 136           |
# |    iterations           | 390           |
# |    time_elapsed         | 23485         |
# |    total_timesteps      | 3194880       |
# | train/                  |               |
# |    approx_kl            | 0.00022171949 |
# |    clip_fraction        | 0.00298       |
# |    clip_range           | 0.236         |
# |    entropy_loss         | -0.0458       |
# |    explained_variance   | 0.69          |
# |    learning_rate        | 1.43e-06      |
# |    loss                 | 0.236         |
# |    n_updates            | 21210         |
# |    policy_gradient_loss | 0.000517      |
# |    value_loss           | 12.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 391          |
# |    time_elapsed         | 23546        |
# |    total_timesteps      | 3203072      |
# | train/                  |              |
# |    approx_kl            | 0.0006497122 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.149       |
# |    explained_variance   | -3.36        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0283       |
# |    n_updates            | 21220        |
# |    policy_gradient_loss | -0.00069     |
# |    value_loss           | 0.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.13e+04     |
# |    ep_rew_mean          | -51.4        |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 392          |
# |    time_elapsed         | 23608        |
# |    total_timesteps      | 3211264      |
# | train/                  |              |
# |    approx_kl            | 0.0008134687 |
# |    clip_fraction        | 0.00447      |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.2         |
# |    explained_variance   | -2.43        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0314       |
# |    n_updates            | 21230        |
# |    policy_gradient_loss | 0.000416     |
# |    value_loss           | 0.0594       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.18e+04     |
# |    ep_rew_mean          | -48          |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 393          |
# |    time_elapsed         | 23669        |
# |    total_timesteps      | 3219456      |
# | train/                  |              |
# |    approx_kl            | 0.0011376241 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | -0.165       |
# |    explained_variance   | -5.34        |
# |    learning_rate        | 1.43e-06     |
# |    loss                 | 0.0155       |
# |    n_updates            | 21240        |
# |    policy_gradient_loss | -0.000454    |
# |    value_loss           | 0.043        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.18e+04      |
# |    ep_rew_mean          | -48           |
# | time/                   |               |
# |    fps                  | 136           |
# |    iterations           | 394           |
# |    time_elapsed         | 23730         |
# |    total_timesteps      | 3227648       |
# | train/                  |               |
# |    approx_kl            | 0.00019956724 |
# |    clip_fraction        | 0.00309       |
# |    clip_range           | 0.236         |
# |    entropy_loss         | -0.134        |
# |    explained_variance   | 0.893         |
# |    learning_rate        | 1.43e-06      |
# |    loss                 | 1.53          |
# |    n_updates            | 21250         |
# |    policy_gradient_loss | -0.000521     |
# |    value_loss           | 11.3          |
# -------------------------------------------

# %%
model.save("train/old_gen/PPO_Sonic_lvl1.zip")

# %% [markdown]
# # Creating New Model And Loading Parameters of Diffrent One

# %%
# Best params
parameters = {'gamma': 0.9905260007134729, 
              'n_steps': 6_144, 
              'learning_rate': 8.0670099142727265e-06, 
              'clip_range': 0.1865481147395506, 
              'gae_lambda': 0.9758617427012113
             }

# %%
model = PPO('CnnPolicy', env, **parameters, tensorboard_log=LOG_DIR, verbose=1)

# %%
model.set_parameters("train/old_gen/PPO-Sonic-Agent")

# %%
# Training
model.learn(total_timesteps=6_000_000, callback=callback)

# %%
model.save("train/old_gen/Sonic_PPO_lvl1.zip")

# %% [markdown]
# # Curriculum Learning

# %%
# Best model
model = PPO.load('train/old_gen/PPO-Sonic-Agent', verbose=1, tensorboard_log=LOG_DIR)

# Displaying current learning rate 
print(model.learning_rate)
print(model.n_steps)

# %%
# Lowering learning rate if needed
model.learning_rate = 100
print(model.learning_rate)

# %%
# Deleting any existing environment
env.close()
del env

# %%
# Training agent on many levels [0,1,8,9,10,11,14,16]
for _ in range(1):
    for i in [8,9]:
        # Creating env
        env = Sonic()
        env.level(i)
        env = ActionDiscretizer(env)
        env = Monitor(env, LOG_DIR)
        env = DummyVecEnv([lambda: env])
        env = VecFrameStack(env, 4, channels_order='last')

        # Setting env
        model.set_env(env)
        # Training
        model.learn(total_timesteps=500_000, callback=callback)

        #closing env
        env.close()
        del env

# %%
model.save("train/PPO-Curriculum-Sonic-Agent.zip")
